# %%
record = {100: {"name":"Coke" , "category": "softdrink", "price" :40 , "available_quantity": 100 , "expiry_year":2025 }, 
          
          101: {"name":"pepsi" , "category":"softdrink" , "price" :38 , "available_quantity":100 , "expiry_year":2024 },

          102: {"name":"thumsup" , "category":"softdrink" , "price" :40 , "available_quantity":100 , "expiry_year":2025 },

          103: {"name":"fanta", "category":"softdrink" , "price" :38 , "available_quantity":98 , "expiry_year":2025 },

          104: {"name":"marinda" , "category": "softdrink", "price" :37 , "available_quantity":95 , "expiry_year":2024 },

          105: {"name":"sprite" , "category": "softdrink", "price" :40 , "available_quantity":100 , "expiry_year":2025 },

          106: {"name":"limca" , "category":"softdrink" , "price" :38 , "available_quantity": 100, "expiry_year": 2025},

          107: {"name": "Dairymilk_silk", "category":"chocolate" , "price" : 80, "available_quantity":150 , "expiry_year":2026 },

          108: {"name":"Dairymilk_fruitandnut" , "category":"chocolate" , "price" :40 , "available_quantity":120 , "expiry_year":2026 },

          109: {"name":"Dairymilk_crackel" , "category":"chocolate" , "price" : 50 , "available_quantity":120 , "expiry_year":2026 },
          
          110: {"name":"Dairymilk_bubbly" , "category":"chocolate" , "price" :80 , "available_quantity":150 , "expiry_year":2026 },
          
          111: {"name":"Mars" , "category":"chocolate" , "price" :80 , "available_quantity":150 , "expiry_year":2025 },
          
          112: {"name":"bounty" , "category":"chocolate" , "price" :90 , "available_quantity":110 , "expiry_year":2026 },
          
          113: {"name":"5star" , "category":"chocolate" , "price" :30 , "available_quantity":150 , "expiry_year":2026 },
          
          114: {"name":"kitkat" , "category":"chocolate" , "price" :40 , "available_quantity":150 , "expiry_year":2026 },
          
          115: {"name":"lindt" , "category":"chocolate" , "price" :90 , "available_quantity":100 , "expiry_year":2026 },
          
          116: {"name":"lays" , "category":"chips" , "price" :30 , "available_quantity":200 , "expiry_year":2026 },
          
          117: {"name":"uncle_chips" , "category":"chips" , "price" :30 , "available_quantity":200 , "expiry_year":2026 },
          
          118: {"name":"pringle" , "category":"chips", "price" :100 , "available_quantity":150 , "expiry_year":2025 },
          
          119: {"name":"too_yum" , "category":"chips" , "price" :20 , "available_quantity":150 , "expiry_year":2025 },
          
          120: {"name":"haldirams_chips" , "category":"chips" , "price" :50 , "available_quantity":150 , "expiry_year":2026 },
          
          121: {"name":"dove" , "category":"soap" , "price" :30 , "available_quantity":200 , "expiry_year":2030 },
          
          122: {"name":"lux" , "category":"soap" , "price" :25 , "available_quantity":200 , "expiry_year":2030 },
          
          123: {"name":"joy" , "category":"soap" , "price" :25 , "available_quantity":200 , "expiry_year":2028 },
          
          124: {"name":"nirma" , "category":"soap" , "price" :25 , "available_quantity":180 , "expiry_year":2028 },
          
          125: {"name":"bru" , "category":"coffee" , "price" :90 , "available_quantity":200 , "expiry_year":2030 },
          
          126: {"name": "nescafe", "category": "coffee", "price" :100 , "available_quantity":200 , "expiry_year":2030 },
          
          127: {"name":"bru_gold" , "category":"coffee" , "price" :150 , "available_quantity":150 , "expiry_year":2030 },
          
          128: {"name":"davidoff" , "category":"coffee" , "price" :200 , "available_quantity":100 , "expiry_year":2030 },
          
          129: {"name":"countrybean" , "category":"coffee" , "price" :140 , "available_quantity":120 , "expiry_year":2030 },
          
          130: {"name":"nescafe_gold" , "category":"coffee" , "price" :200 , "available_quantity":150 , "expiry_year":2030 },
          
          131: {"name": "starbucks_houseblend", "category":"coffee" , "price" :300 , "available_quantity": 100, "expiry_year": 2030}}

# %%
record
# Out:
# {100: {'available_quantity': 100,
#   'category': 'softdrink',
#   'expiry_year': 2025,
#   'name': 'Coke',
#   'price': 40},
#  101: {'available_quantity': 100,
#   'category': 'softdrink',
#   'expiry_year': 2024,
#   'name': 'pepsi',
#   'price': 38},
#  102: {'available_quantity': 100,
#   'category': 'softdrink',
#   'expiry_year': 2025,
#   'name': 'thumsup',
#   'price': 40},
#  103: {'available_quantity': 98,
#   'category': 'softdrink',
#   'expiry_year': 2025,
#   'name': 'fanta',
#   'price': 38},
#  104: {'available_quantity': 95,
#   'category': 'softdrink',
#   'expiry_year': 2024,
#   'name': 'marinda',
#   'price': 37},
#  105: {'available_quantity': 100,
#   'category': 'softdrink',
#   'expiry_year': 2025,
#   'name': 'sprite',
#   'price': 40},
#  106: {'available_quantity': 100,
#   'category': 'softdrink',
#   'expiry_year': 2025,
#   'name': 'limca',
#   'price': 38},
#  107: {'available_quantity': 150,
#   'category': 'chocolate',
#   'expiry_year': 2026,
# ...

# %%
import json

# %%
js = json.dumps(record)

# %%
js
# Out:
# '{"100": {"name": "Coke", "category": "softdrink", "price": 40, "available_quantity": 100, "expiry_year": 2025}, "101": {"name": "pepsi", "category": "softdrink", "price": 38, "available_quantity": 100, "expiry_year": 2024}, "102": {"name": "thumsup", "category": "softdrink", "price": 40, "available_quantity": 100, "expiry_year": 2025}, "103": {"name": "fanta", "category": "softdrink", "price": 38, "available_quantity": 98, "expiry_year": 2025}, "104": {"name": "marinda", "category": "softdrink", "price": 37, "available_quantity": 95, "expiry_year": 2024}, "105": {"name": "sprite", "category": "softdrink", "price": 40, "available_quantity": 100, "expiry_year": 2025}, "106": {"name": "limca", "category": "softdrink", "price": 38, "available_quantity": 100, "expiry_year": 2025}, "107": {"name": "Dairymilk_silk", "category": "chocolate", "price": 80, "available_quantity": 150, "expiry_year": 2026}, "108": {"name": "Dairymilk_fruitandnut", "category": "chocolate", "price": 40, "available
# ...

# %%
fd = open("record.json" , 'w')
fd.write(js)
fd.close()

# %%
fd = open("record.json",'r')

txt = fd.read()

fd.close()

# %%
txt
# Out:
# '{"100": {"name": "Coke", "category": "softdrink", "price": 40, "available_quantity": 100, "expiry_year": 2025}, "101": {"name": "pepsi", "category": "softdrink", "price": 38, "available_quantity": 100, "expiry_year": 2024}, "102": {"name": "thumsup", "category": "softdrink", "price": 40, "available_quantity": 100, "expiry_year": 2025}, "103": {"name": "fanta", "category": "softdrink", "price": 38, "available_quantity": 98, "expiry_year": 2025}, "104": {"name": "marinda", "category": "softdrink", "price": 37, "available_quantity": 95, "expiry_year": 2024}, "105": {"name": "sprite", "category": "softdrink", "price": 40, "available_quantity": 100, "expiry_year": 2025}, "106": {"name": "limca", "category": "softdrink", "price": 38, "available_quantity": 100, "expiry_year": 2025}, "107": {"name": "Dairymilk_silk", "category": "chocolate", "price": 80, "available_quantity": 150, "expiry_year": 2026}, "108": {"name": "Dairymilk_fruitandnut", "category": "chocolate", "price": 40, "available
# ...

# %%
records = json.loads(txt)

# %%
records
# Out:
# {'100': {'available_quantity': 100,
#   'category': 'softdrink',
#   'expiry_year': 2025,
#   'name': 'Coke',
#   'price': 40},
#  '101': {'available_quantity': 100,
#   'category': 'softdrink',
#   'expiry_year': 2024,
#   'name': 'pepsi',
#   'price': 38},
#  '102': {'available_quantity': 100,
#   'category': 'softdrink',
#   'expiry_year': 2025,
#   'name': 'thumsup',
#   'price': 40},
#  '103': {'available_quantity': 98,
#   'category': 'softdrink',
#   'expiry_year': 2025,
#   'name': 'fanta',
#   'price': 38},
#  '104': {'available_quantity': 95,
#   'category': 'softdrink',
#   'expiry_year': 2024,
#   'name': 'marinda',
#   'price': 37},
#  '105': {'available_quantity': 100,
#   'category': 'softdrink',
#   'expiry_year': 2025,
#   'name': 'sprite',
#   'price': 40},
#  '106': {'available_quantity': 100,
#   'category': 'softdrink',
#   'expiry_year': 2025,
#   'name': 'limca',
#   'price': 38},
#  '107': {'available_quantity': 150,
#   'category': 'chocolate',
# ...

# %%
prod_id = int((input("Enter the product id: "))) 
if (prod_id in record.keys()) :
  print("Product Exist")
  product_quantity = int(input("Enter quantity to be added: "))
  record[prod_id]['available_quantity'] = record[prod_id]['available_quantity'] + product_quantity
else:
  prod_name = (input("Enter name: "))
  prod_category = (input("Enter Catergory: "))
  price = int(input("Enter price: "))
  product_quantity = int(input("Enter the quantity: "))
  expiry_year = int(input("Enter expiry year: "))
  record[prod_id] = {"name": prod_name, "category": prod_category , "price" : price , "available_quantity": product_quantity , "expiry_year":expiry_year }

js = json.dumps(record)

fd = open("record.json",'w')
fd.write(js)
fd.close()
# Out:
# Enter the product id: 120
# Product Exist
# Enter quantity to be added: 30

# %%
record
# Out:
# {100: {'available_quantity': 100,
#   'category': 'softdrink',
#   'expiry_year': 2025,
#   'name': 'Coke',
#   'price': 40},
#  101: {'available_quantity': 100,
#   'category': 'softdrink',
#   'expiry_year': 2024,
#   'name': 'pepsi',
#   'price': 38},
#  102: {'available_quantity': 100,
#   'category': 'softdrink',
#   'expiry_year': 2025,
#   'name': 'thumsup',
#   'price': 40},
#  103: {'available_quantity': 98,
#   'category': 'softdrink',
#   'expiry_year': 2025,
#   'name': 'fanta',
#   'price': 38},
#  104: {'available_quantity': 95,
#   'category': 'softdrink',
#   'expiry_year': 2024,
#   'name': 'marinda',
#   'price': 37},
#  105: {'available_quantity': 100,
#   'category': 'softdrink',
#   'expiry_year': 2025,
#   'name': 'sprite',
#   'price': 40},
#  106: {'available_quantity': 100,
#   'category': 'softdrink',
#   'expiry_year': 2025,
#   'name': 'limca',
#   'price': 38},
#  107: {'available_quantity': 150,
#   'category': 'chocolate',
#   'expiry_year': 2026,
# ...
